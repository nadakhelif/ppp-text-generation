# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.4 MB/s eta 0:00:00
# ...

# %%
from transformers import GPT2LMHeadModel , GPT2Tokenizer

# %%
tokenizer= GPT2Tokenizer.from_pretrained('gpt2')
model=GPT2LMHeadModel.from_pretrained('gpt2',pad_token_id=tokenizer.eos_token_id)

# %%
tokenizer.eos_token_id
# Out:
# 50256

# %%
sentence ="IA will replace man soon"

input_ids = tokenizer.encode(sentence, return_tensors='pt')

# %%
output = model.generate(input_ids,
        max_length=500,
        temperature=0.7,
        do_sample=True,
        top_p=0.9,
        top_k=50)

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# "IA will replace man soon.\n\nWe are also starting a new project to help solve the problem of the internet in India.\n\nWe are the first to offer the internet to Indians, to give them a better way to communicate.\n\nWe are building a network of people who will become internet engineers in the next 10 years.\n\nWe will take our country's biggest companies to the next level.\n\nWe will make our country more like Germany, where people are free to build their own homes and homes for themselves.\n\nWe will make our country more like the United States of America where people can build their own houses for themselves.\n\nWe will build a world where people can be connected to one another and live together in peace, harmony and self-respect.\n\nWe will bring our country together by empowering the people to build their own homes and homes for themselves.\n\nWe will bring the people together by connecting them to their own homes.\n\nWe will build a world where people can live together in peace 
# ...

# %% [markdown]
# to save the text in a file !

# %%
text=tokenizer.decode(output[0], skip_special_tokens=True)

# %%
with open('blog.txt','w') as f : 
  f.write(text)

# %% [markdown]
# *   STEP1 : installing transformers (libraby that contains gpt2)
# *   STEP2: load model
# *   STEP3 : generate and decode text
# *   STEP4 : generate and decode Text
# *   STEP5 : Output Result
